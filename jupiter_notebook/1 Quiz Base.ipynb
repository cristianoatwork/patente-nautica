# %%
import pandas as pd
#import tabula

#list_of_dfs = tabula.read_pdf("xlsx/ALLEGATO A QUIZ PATENTI NAUTICHE DD 131 DEL 31 MAGGIO 2022.pdf", pages = 'all')
#result_df = pd.concat(list_of_dfs)
#result_df.to_excel('xlsx/ALLEGATO2.xlsx')

# %%
QUIZ_BASE_START_ROW = 1
QUIZ_BASE_END_ROW   = 1719
QUIZ_BASE_COLUMNS = "A,C,G,W:BG"

# %%
df = pd.read_excel("xlsx/ALLEGATO A QUIZ PATENTI NAUTICHE DD 131 DEL 31 MAGGIO 2022.xlsx",
                   #index_col=0,
                   skiprows=lambda x: x < QUIZ_BASE_START_ROW,
                   usecols="A,C,G,W,AA,AB,AK,AM,AS,AT,AX,BB,BG",
                   nrows=QUIZ_BASE_END_ROW-QUIZ_BASE_START_ROW-1
                  )
df.head(13)
# Out:
#     Unnamed: 0   IMMAGINE                                            DOMANDA  \
# 0          1.0        NaN  Com'è denominata la massima lunghezza dell'uni...
# 1          2.0        NaN  Cosa si intende per asse longitudinale di un'u...
# 2          3.0        NaN  Quale funzione svolge la sentina di un'unità n...
# 3          4.0        NaN                                    Le murate sono:
# 4          5.0        NaN                         Cos'è il ponte di coperta?
# 5          NaN   IMMAGINE                                            DOMANDA
# 6          6.0        NaN               Cosa si intende per prua dell'unità?
# 7          7.0        NaN             Cosa si intende per poppa di un'unità?
# 8          8.0        NaN  Cosa si intende per specchio di poppa di un'un...
# 9          9.0        NaN  Cosa si intende per locale macchine o locale a...
# 10        10.0  figura001  Con riferimento alla figura, quale porzione de...
# ...

# %%
#df.iloc[1:10, 0].notna()

# %%
# Find label of the first row where the value 'Test' is found (within column 0)
tf = df.iloc[:, 0].notna()
df.loc[tf, :]
# Out:
#       Unnamed: 0 IMMAGINE                                            DOMANDA  \
# 0            1.0      NaN  Com'è denominata la massima lunghezza dell'uni...
# 1            2.0      NaN  Cosa si intende per asse longitudinale di un'u...
# 2            3.0      NaN  Quale funzione svolge la sentina di un'unità n...
# 3            4.0      NaN                                    Le murate sono:
# 4            5.0      NaN                         Cos'è il ponte di coperta?
# ...          ...      ...                                                ...
# 1711      1468.0      NaN  Generalmente, in zona A delle Aree Marine Prot...
# 1712      1469.0      NaN  L’interruzione immediata e definitiva delle ca...
# 1714      1470.0      NaN  Nelle aree marine protette in zona B (riserva ...
# 1715      1471.0      NaN     I contenitori di plastica abbandonata in mare:
# 1716      1472.0      NaN  Nelle aree marine protette dove l'ormeggio è r...
#
# ...

# %%
df.head()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'IMMAGINE', 'DOMANDA', 'RISPOSTA 1', 'V/F', 'RSPOSTA 2',
#        'V/F.1', 'RISPOSTA 3', 'V/F.2', 'PROGRESSIVO', 'CAPITOLO', 'TEMA',
#        'VOCE'],
#       dtype='object')

# %%
df.index.is_unique

# %%
# df.loc[df[].duplicated(keep=False), :]

df["Unnamed: 20"].unique()
# Out:
# array([nan])

# %%
df.tail()
