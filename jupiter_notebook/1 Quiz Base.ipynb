# %%
import pandas as pd

# %%
df = pd.read_excel("xlsx/ALLEGATO A QUIZ PATENTI NAUTICHE DD 131 DEL 31 MAGGIO 2022.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2444 entries, 0 to 2443
# Data columns (total 62 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   QUIZ BASE    2132 non-null   object
#  1   Unnamed: 1   32 non-null     object
#  2   Unnamed: 2   246 non-null    object
#  3   Unnamed: 3   76 non-null     object
#  4   Unnamed: 4   282 non-null    object
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   1718 non-null   object
#  7   Unnamed: 7   1 non-null      float64
#  8   Unnamed: 8   3 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  77 non-null     object
#  12  Unnamed: 12  1 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  1 non-null      float64
#  15  Unnamed: 15  81 non-null     object
#  16  Unnamed: 16  1 non-null      object
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
df.loc[1:, :].columns
# Out:
# Index(['QUIZ BASE', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45',
#        'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49',
#        'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53',
#        'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57',
# ...

# %%
df.head()
# Out:
#   QUIZ BASE Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0       NaN        NaN   IMMAGINE        NaN        NaN         NaN
# 1         1        NaN        NaN        NaN        NaN         NaN
# 2         2        NaN        NaN        NaN        NaN         NaN
# 3         3        NaN        NaN        NaN        NaN         NaN
# 4         4        NaN        NaN        NaN        NaN         NaN
#
#                                           Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0                                            DOMANDA         NaN         NaN
# 1  Com'è denominata la massima lunghezza dell'uni...         NaN         NaN
# 2  Cosa si intende per asse longitudinale di un'u...         NaN         NaN
# 3  Quale funzione svolge la sentina di un'unità n...         NaN         NaN
# 4                                    Le murate sono:         NaN         NaN
#
#    Unnamed: 9  ...  Unnamed: 52         Unnamed: 53  Unnamed: 54  Unnamed: 55  \
# ...
